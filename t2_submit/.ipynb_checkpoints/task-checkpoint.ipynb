# %% [markdown]
# ## [분야2] 서비스 품질 보장을 위한 플로우 특성 실시간 식별 베이스라인 코드
# #### 주의: 반드시 본 파일을 이용하여 제출을 수행해야 하며 파일의 이름은 task.ipynb로 유지되어야 합니다.
#
# ### 추론 실행 환경
# 1. python 3.10 환경
# 2. torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
#     - 최신 버전입니다.
#
# 코드는 크게 3가지 파트로 구성되며, 해당 파트의 특성을 지켜서 내용을 편집하시면 되겠습니다.
# 1. 제출용 aifactory 라이브러리 및 추가 필요 라이브러리 설치
#     - 채점 및 제출을 위한 aifactory 라이브러리를 설치하는 셀입니다. 이 부분은 수정하지 않고 그대로 실행합니다.
#     - 필요 라이브러리를 직접 설치합니다.
# 2. 추론용 코드 작성
#     - 모델 로드, 데이터 전처리, 예측 등 실제 추론을 수행하는 모든 코드를 이 영역에 작성합니다.
# 3. aif.submit() 함수를 호출하여 최종 결과를 제출하는 파트입니다.
#     - 마이 페이지에서 발급받은 key 값을 함수의 인자로 정확히 입력해야 합니다.
#
# ※ 가능하면 제출시에는 포함되어 있는 train data를 폴더에서 제외하고 제출하시는 편이 좋습니다.
#     - 파일 크기 감소 → 업로드 시간 감소 → 전체 추론 수행 시간 감소

# %% [markdown]
# ### 1. 제출용 aifactory 라이브러리 설치
# #### 결과 전송에 필요하므로 아래와 같이 aifactory 라이브러리가 반드시 최신버전으로 설치될 수 있게끔 합니다

# %%
# !pip install -U aifactory
# Out:
# Requirement already satisfied: aifactory in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (2.0.0)
# Requirement already satisfied: pipreqs in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from aifactory) (0.4.13)
# Requirement already satisfied: ipynbname in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from aifactory) (2024.1.0.0)
# Requirement already satisfied: gdown in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from aifactory) (5.2.0)
# Requirement already satisfied: requests in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from aifactory) (2.32.4)
# Requirement already satisfied: IPython in c:\users\hg226\appdata\roaming\python\python313\site-packages (from aifactory) (9.0.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from gdown->aifactory) (4.13.4)
# Requirement already satisfied: filelock in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from gdown->aifactory) (3.18.0)
# Requirement already satisfied: tqdm in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from gdown->aifactory) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4->gdown->aifactory) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4->gdown->aifactory) (4.14.0)
# Requirement already satisfied: ipykernel in c:\users\hg226\appdata\roaming\python\python313\site-packages (from ipynbname->aifactory) (6.29.5)
# Requirement already satisfied: comm>=0.1.1 in c:\users\hg226\appdata\roaming\python\python313\site-packages (from ipykernel->ipynbname->aifactory) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\hg226\appdata\roaming\python\python313\site-packages (from ipykernel->ipynbname->aifactory) (1.8.13)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\hg226\appdata\roaming\python\python313\site-packages (from ipykernel->ipynbname->aifactory) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\hg226\appdata\roaming\python\python313\site-packages (from ipykernel->ipynbname->aifactory) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\hg226\appdata\roaming\python\python313\site-packages (from ipykernel->ipynbname->aifactory) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\hg226\appdata\roaming\python\python313\site-packages (from ipykernel->ipynbname->aifactory) (1.6.0)
# Requirement already satisfied: packaging in c:\users\hg226\appdata\roaming\python\python313\site-packages (from ipykernel->ipynbname->aifactory) (24.2)
# Requirement already satisfied: psutil in c:\users\hg226\appdata\roaming\python\python313\site-packages (from ipykernel->ipynbname->aifactory) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\hg226\appdata\roaming\python\python313\site-packages (from ipykernel->ipynbname->aifactory) (26.3.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\hg226\appdata\roaming\python\python313\site-packages (from ipykernel->ipynbname->aifactory) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\hg226\appdata\roaming\python\python313\site-packages (from ipykernel->ipynbname->aifactory) (5.14.3)
# Requirement already satisfied: colorama in c:\users\hg226\appdata\roaming\python\python313\site-packages (from IPython->aifactory) (0.4.6)
# Requirement already satisfied: decorator in c:\users\hg226\appdata\roaming\python\python313\site-packages (from IPython->aifactory) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\hg226\appdata\roaming\python\python313\site-packages (from IPython->aifactory) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\hg226\appdata\roaming\python\python313\site-packages (from IPython->aifactory) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\hg226\appdata\roaming\python\python313\site-packages (from IPython->aifactory) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\hg226\appdata\roaming\python\python313\site-packages (from IPython->aifactory) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\hg226\appdata\roaming\python\python313\site-packages (from IPython->aifactory) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\hg226\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython->aifactory) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\hg226\appdata\roaming\python\python313\site-packages (from jedi>=0.16->IPython->aifactory) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hg226\appdata\roaming\python\python313\site-packages (from jupyter-client>=6.1.12->ipykernel->ipynbname->aifactory) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\hg226\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->ipynbname->aifactory) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\hg226\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->ipynbname->aifactory) (309)
# Requirement already satisfied: six>=1.5 in c:\users\hg226\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel->ipynbname->aifactory) (1.17.0)
# Requirement already satisfied: docopt in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from pipreqs->aifactory) (0.6.2)
# Requirement already satisfied: yarg in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from pipreqs->aifactory) (0.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from requests->aifactory) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from requests->aifactory) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from requests->aifactory) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from requests->aifactory) (2025.4.26)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from requests[socks]->gdown->aifactory) (1.7.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\hg226\appdata\roaming\python\python313\site-packages (from stack_data->IPython->aifactory) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\hg226\appdata\roaming\python\python313\site-packages (from stack_data->IPython->aifactory) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\hg226\appdata\roaming\python\python313\site-packages (from stack_data->IPython->aifactory) (0.2.3)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 자신의 모델에 필요한 추가 라이브러리 설치
# !pip install -U pytorch-lightning==2.0.9
# !pip install -U scikit-learn==1.3.0
# !pip install -U numpy==1.23.5
# !pip install pexpect
# !pip install decorator
# !pip install certifi
# Out:
# Collecting pytorch-lightning==2.0.9
#   Downloading pytorch_lightning-2.0.9-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: numpy>=1.17.2 in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from pytorch-lightning==2.0.9) (2.2.3)
# Requirement already satisfied: torch>=1.11.0 in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from pytorch-lightning==2.0.9) (2.7.1)
# Requirement already satisfied: tqdm>=4.57.0 in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from pytorch-lightning==2.0.9) (4.67.1)
# Requirement already satisfied: PyYAML>=5.4 in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from pytorch-lightning==2.0.9) (6.0.2)
# Requirement already satisfied: fsspec>2021.06.0 in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from fsspec[http]>2021.06.0->pytorch-lightning==2.0.9) (2025.5.1)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning==2.0.9)
#   Downloading torchmetrics-1.8.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: packaging>=17.1 in c:\users\hg226\appdata\roaming\python\python313\site-packages (from pytorch-lightning==2.0.9) (24.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from pytorch-lightning==2.0.9) (4.14.0)
# Collecting lightning-utilities>=0.7.0 (from pytorch-lightning==2.0.9)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>2021.06.0->pytorch-lightning==2.0.9)
#   Downloading aiohttp-3.12.15-cp313-cp313-win_amd64.whl.metadata (7.9 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.0.9)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.0.9)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.0.9)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.0.9)
#   Downloading frozenlist-1.7.0-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.0.9)
#   Downloading multidict-6.6.3-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.0.9)
#   Downloading propcache-0.3.2-cp313-cp313-win_amd64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.0.9)
#   Downloading yarl-1.20.1-cp313-cp313-win_amd64.whl.metadata (76 kB)
# Requirement already satisfied: idna>=2.0 in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.0.9) (3.10)
# Requirement already satisfied: setuptools in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from lightning-utilities>=0.7.0->pytorch-lightning==2.0.9) (80.9.0)
# Requirement already satisfied: filelock in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->pytorch-lightning==2.0.9) (3.18.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->pytorch-lightning==2.0.9) (1.14.0)
# Requirement already satisfied: networkx in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->pytorch-lightning==2.0.9) (3.5)
# Requirement already satisfied: jinja2 in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->pytorch-lightning==2.0.9) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->pytorch-lightning==2.0.9) (1.3.0)
# Requirement already satisfied: colorama in c:\users\hg226\appdata\roaming\python\python313\site-packages (from tqdm>=4.57.0->pytorch-lightning==2.0.9) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch>=1.11.0->pytorch-lightning==2.0.9) (3.0.2)
# Downloading pytorch_lightning-2.0.9-py3-none-any.whl (727 kB)
#    ---------------------------------------- 0.0/727.7 kB ? eta -:--:--
#    ---------------------------------------- 727.7/727.7 kB 6.8 MB/s eta 0:00:00
# Downloading aiohttp-3.12.15-cp313-cp313-win_amd64.whl (449 kB)
# Downloading multidict-6.6.3-cp313-cp313-win_amd64.whl (45 kB)
# Downloading yarl-1.20.1-cp313-cp313-win_amd64.whl (86 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading frozenlist-1.7.0-cp313-cp313-win_amd64.whl (43 kB)
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading propcache-0.3.2-cp313-cp313-win_amd64.whl (40 kB)
# Downloading torchmetrics-1.8.0-py3-none-any.whl (981 kB)
#    ---------------------------------------- 0.0/981.9 kB ? eta -:--:--
#    ---------------------------------------- 981.9/981.9 kB 7.9 MB/s eta 0:00:00
# Installing collected packages: propcache, multidict, lightning-utilities, frozenlist, attrs, aiohappyeyeballs, yarl, aiosignal, torchmetrics, aiohttp, pytorch-lightning
#
#    --- ------------------------------------  1/11 [multidict]
#    ------- --------------------------------  2/11 [lightning-utilities]
#    ------- --------------------------------  2/11 [lightning-utilities]
#    ------- --------------------------------  2/11 [lightning-utilities]
#    ------- --------------------------------  2/11 [lightning-utilities]
#    -------------- -------------------------  4/11 [attrs]
#    -------------- -------------------------  4/11 [attrs]
#    -------------- -------------------------  4/11 [attrs]
#    -------------- -------------------------  4/11 [attrs]
#    -------------- -------------------------  4/11 [attrs]
#    ------------------ ---------------------  5/11 [aiohappyeyeballs]
#    --------------------- ------------------  6/11 [yarl]
#    --------------------- ------------------  6/11 [yarl]
#    ------------------------- --------------  7/11 [aiosignal]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    ----------------------------- ----------  8/11 [torchmetrics]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ------------------------------------ --- 10/11 [pytorch-lightning]
#    ---------------------------------------- 11/11 [pytorch-lightning]
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 attrs-25.3.0 frozenlist-1.7.0 lightning-utilities-0.15.2 multidict-6.6.3 propcache-0.3.2 pytorch-lightning-2.0.9 torchmetrics-1.8.0 yarl-1.20.1
# WARNING: Ignoring invalid distribution ~andas (C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting scikit-learn==1.3.0
#   Downloading scikit-learn-1.3.0.tar.gz (7.5 MB)
#      ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#      ---- ----------------------------------- 0.8/7.5 MB 5.1 MB/s eta 0:00:02
#      --------- ------------------------------ 1.8/7.5 MB 5.1 MB/s eta 0:00:02
#      -------------- ------------------------- 2.6/7.5 MB 4.7 MB/s eta 0:00:02
#      --------------------- ------------------ 3.9/7.5 MB 5.2 MB/s eta 0:00:01
#      -------------------------- ------------- 5.0/7.5 MB 5.3 MB/s eta 0:00:01
#      --------------------------------- ------ 6.3/7.5 MB 5.5 MB/s eta 0:00:01
#      ---------------------------------------- 7.5/7.5 MB 5.4 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
# WARNING: Ignoring invalid distribution ~andas (C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\site-packages)
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [45 lines of output]
#       Partial import of sklearn during the build process.
#       Traceback (most recent call last):
#         File "C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
#           main()
#           ~~~~^^
#         File "C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 175, in prepare_metadata_for_build_wheel
#           return hook(metadata_directory, config_settings)
#         File "C:\Users\hg226\AppData\Local\Temp\pip-build-env-xqijgq4w\overlay\Lib\site-packages\setuptools\build_meta.py", line 374, in prepare_metadata_for_build_wheel
#           self.run_setup()
#           ~~~~~~~~~~~~~~^^
#         File "C:\Users\hg226\AppData\Local\Temp\pip-build-env-xqijgq4w\overlay\Lib\site-packages\setuptools\build_meta.py", line 512, in run_setup
#           super().run_setup(setup_script=setup_script)
#           ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\hg226\AppData\Local\Temp\pip-build-env-xqijgq4w\overlay\Lib\site-packages\setuptools\build_meta.py", line 317, in run_setup
#           exec(code, locals())
#           ~~~~^^^^^^^^^^^^^^^^
#         File "<string>", line 626, in <module>
#         File "<string>", line 620, in setup_package
#         File "<string>", line 554, in configure_extension_modules
#         File "C:\Users\hg226\AppData\Local\Temp\pip-install-_u3fazt6\scikit-learn_5c2bf9443d88483f8e0ed6fe5b84c75a\sklearn\_build_utils\__init__.py", line 46, in cythonize_extensions
#           basic_check_build()
#           ~~~~~~~~~~~~~~~~~^^
#         File "C:\Users\hg226\AppData\Local\Temp\pip-install-_u3fazt6\scikit-learn_5c2bf9443d88483f8e0ed6fe5b84c75a\sklearn\_build_utils\pre_build_helpers.py", line 73, in basic_check_build
#           compile_test_program(code)
#           ~~~~~~~~~~~~~~~~~~~~^^^^^^
#         File "C:\Users\hg226\AppData\Local\Temp\pip-install-_u3fazt6\scikit-learn_5c2bf9443d88483f8e0ed6fe5b84c75a\sklearn\_build_utils\pre_build_helpers.py", line 31, in compile_test_program
#           ccompiler.compile(
#           ~~~~~~~~~~~~~~~~~^
#               ["test_program.c"], output_dir="objects", extra_postargs=extra_postargs
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#           )
#           ^
#         File "C:\Users\hg226\AppData\Local\Temp\pip-build-env-xqijgq4w\overlay\Lib\site-packages\setuptools\_distutils\compilers\C\msvc.py", line 384, in compile
#           self.initialize()
#           ~~~~~~~~~~~~~~~^^
#         File "C:\Users\hg226\AppData\Local\Temp\pip-build-env-xqijgq4w\overlay\Lib\site-packages\setuptools\_distutils\compilers\C\msvc.py", line 294, in initialize
#           vc_env = _get_vc_env(plat_spec)
#         File "C:\Users\hg226\AppData\Local\Temp\pip-build-env-xqijgq4w\overlay\Lib\site-packages\setuptools\_distutils\compilers\C\msvc.py", line 155, in _get_vc_env
#           raise DistutilsPlatformError(
#           ...<3 lines>...
#           )
#       distutils.errors.DistutilsPlatformError: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Collecting numpy==1.23.5
#   Downloading numpy-1.23.5.tar.gz (10.7 MB)
#      ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#      --- ------------------------------------ 1.0/10.7 MB 5.3 MB/s eta 0:00:02
#      --------- ------------------------------ 2.6/10.7 MB 6.7 MB/s eta 0:00:02
#      ---------------- ----------------------- 4.5/10.7 MB 7.5 MB/s eta 0:00:01
#      ----------------------- ---------------- 6.3/10.7 MB 7.8 MB/s eta 0:00:01
#      ------------------------------- -------- 8.4/10.7 MB 8.4 MB/s eta 0:00:01
#      ---------------------------------------  10.5/10.7 MB 8.9 MB/s eta 0:00:01
#      ---------------------------------------- 10.7/10.7 MB 8.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# WARNING: Ignoring invalid distribution ~andas (C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\site-packages)
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [32 lines of output]
#       Traceback (most recent call last):
#         File "C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
#           main()
#           ~~~~^^
#         File "C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 137, in get_requires_for_build_wheel
#           backend = _build_backend()
#         File "C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 70, in _build_backend
#           obj = import_module(mod_path)
#         File "C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py", line 88, in import_module
#           return _bootstrap._gcd_import(name[level:], package, level)
#                  ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#         File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#         File "<frozen importlib._bootstrap>", line 1310, in _find_and_load_unlocked
#         File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#         File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#         File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#         File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#         File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#         File "<frozen importlib._bootstrap_external>", line 1026, in exec_module
#         File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#         File "C:\Users\hg226\AppData\Local\Temp\pip-build-env-8qzikv8j\overlay\Lib\site-packages\setuptools\__init__.py", line 16, in <module>
#           import setuptools.version
#         File "C:\Users\hg226\AppData\Local\Temp\pip-build-env-8qzikv8j\overlay\Lib\site-packages\setuptools\version.py", line 1, in <module>
#           import pkg_resources
#         File "C:\Users\hg226\AppData\Local\Temp\pip-build-env-8qzikv8j\overlay\Lib\site-packages\pkg_resources\__init__.py", line 2172, in <module>
#           register_finder(pkgutil.ImpImporter, find_on_path)
#                           ^^^^^^^^^^^^^^^^^^^
#       AttributeError: module 'pkgutil' has no attribute 'ImpImporter'. Did you mean: 'zipimporter'?
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Collecting pexpect
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting ptyprocess>=0.5 (from pexpect)
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
# Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Installing collected packages: ptyprocess, pexpect
#
#    -------------------- ------------------- 1/2 [pexpect]
#    -------------------- ------------------- 1/2 [pexpect]
#    -------------------- ------------------- 1/2 [pexpect]
#    ---------------------------------------- 2/2 [pexpect]
#
# Successfully installed pexpect-4.9.0 ptyprocess-0.7.0
# WARNING: Ignoring invalid distribution ~andas (C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: decorator in c:\users\hg226\appdata\roaming\python\python313\site-packages (5.2.1)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: certifi in c:\users\hg226\appdata\local\programs\python\python313\lib\site-packages (2025.4.26)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\hg226\AppData\Local\Programs\Python\Python313\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### 2. 추론 환경의 기본 경로 구조
# #### 제출 시 주의사항
#
# 1. 테스트 데이터 경로: /aif/data/test_packet_data.pkl
#    - 채점에 사용될 테스트 입력 데이터는 이 디렉토리 안에 test_packet_data.pkl이라는 이름으로 고정되어 제공됩니다.
# 2. 모델 및 자원 경로: 예시 : ./model/
#    - 추론 스크립트가 실행되는 위치를 기준으로, 제출된 모델 관련 파일들이 위치하는 상대 경로입니다.
#    - 학습된 모델 가중치(.pt, .ckpt, .pth 등)
# 3. ※ 반드시 입력 패킷 길이 변수명을 반드시 "input_packet_length"로 지정해야 합니다.
#    - 해당 변수명이 누락되거나 다를 경우 "input_packet_length 변수를 정상적으로 정의해야 합니다!"라는 오류가 발생합니다.
# 4. 제출 파일은 submission.pkl로 저장
# 5. argparse 사용시 args, _ = parser.parse_known_args()로 인자 지정
#    args = parser.parse_args()는 jupyter에서 오류가 발생합니다!!!
# 6. return할 결과물과 양식에 유의합니다.

# %%
import os
import numpy as np
import pandas as pd
import joblib
import torch
import torch.nn as nn
import pytorch_lightning as pl
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
import json

# --- 0. 설정 및 초기화 ---
SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(SEED)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# --- 1. 테스트 데이터셋 클래스 정의 ---
class FlowPacketTestDataset(Dataset):
    def __init__(self, packet_data_list, seq_len, features):
        self.packet_data_list = packet_data_list
        self.seq_len = seq_len
        self.features = features
        
    def __len__(self):
        return len(self.packet_data_list)
    
    def __getitem__(self, idx):
        packets_df = self.packet_data_list[idx]
        packets_df = packets_df[self.features]
        x = packets_df.head(self.seq_len)
        
        # 패딩 처리 (안전장치)
        x_values = x.values.astype(np.float32)
        if len(x_values) < self.seq_len:
            pad_len = self.seq_len - len(x_values)
            padding = np.zeros((pad_len, x_values.shape[1]), dtype=np.float32)
            x_values = np.vstack([x_values, padding])
            
        x_tensor = torch.FloatTensor(x_values)
        return x_tensor

# --- 2. 추론 전용 모델 클래스 정의 (nn.Module 사용) ---
class InferenceModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super().__init__()
        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=1,
            batch_first=True
        )
        self.head_duration = nn.Linear(hidden_size, num_classes)
        self.head_volume = nn.Linear(hidden_size, num_classes)
        
    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        last_output = lstm_out[:, -1, :]
        logits_duration = self.head_duration(last_output)
        logits_volume = self.head_volume(last_output)
        return logits_duration, logits_volume

# --- 3. 저장된 모델과 메타데이터 로드 함수 ---
def load_model_components(model_name, model_path):
    meta_path = os.path.join(model_path, f'{model_name}_meta.json')
    model_weights_path = os.path.join(model_path, f'{model_name}.pth')
    
    print(f"메타데이터 로딩: {meta_path}")
    with open(meta_path, 'r') as f:
        metadata = json.load(f)

    # InferenceModel 클래스 사용
    model = InferenceModel(
        input_size=metadata['input_size'],
        hidden_size=metadata['hidden_size'],
        num_classes=metadata['num_classes']
    )
    
    model.load_state_dict(torch.load(model_weights_path, map_location=device))
    model.to(device)
    model.eval()
    return model, metadata

# --- 4. 데이터 로드 및 모델 컴포넌트 준비 ---
test_packet_data = joblib.load("/aif/data/test_packet_data.pkl")
MODEL_DIR = "./model" 
MODEL_NAME = "traffic_multitask_lstm"
model, metadata = load_model_components(model_name=MODEL_NAME, model_path=MODEL_DIR)

# --- 5. 테스트 데이터셋 및 데이터로더 생성 ---
test_dataset = FlowPacketTestDataset(
    packet_data_list=test_packet_data,
    seq_len=metadata['seq_len'],
    features=metadata['packet_features']
)
BATCH_SIZE = 256 
test_loader = DataLoader(
    test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=1
)

# --- 6. 추론 실행 ---
pred_duration = []
pred_volume = []
with torch.no_grad():
    for x_batch in tqdm(test_loader, desc="[base_line]"):
        x_batch = x_batch.to(device)
        logits_duration, logits_volume = model(x_batch)
        preds_d = torch.argmax(logits_duration, dim=1)
        preds_v = torch.argmax(logits_volume, dim=1)
        pred_duration.append(preds_d.cpu().numpy())
        pred_volume.append(preds_v.cpu().numpy())

# --- 7. 결과 취합 ---
y_pred_duration = np.concatenate(pred_duration, axis=0)
y_pred_volume = np.concatenate(pred_volume, axis=0)
# 예측 결과를 딕셔너리로 묶음
submission_dict = {
    'duration_class': y_pred_duration,
    'volume_class': y_pred_volume
}

# 딕셔너리를 Pandas DataFrame으로 변환
submission_df = pd.DataFrame(submission_dict)

input_packet_length = 3
# DataFrame을 pkl 파일로 저장
submission_path = "submission.pkl"
joblib.dump(submission_df, submission_path)

# %% [markdown]
# ### 3. 제출하기
# #### ※ task별, 참가자별로 key가 다릅니다. 잘못 입력하지 않도록 유의바랍니다.
# - key는 대회 페이지 [베이스라인 코드](https://aifactory.space/task/9163/baseline) 탭에 기재된 가이드라인을 따라 task별로 확인하실 수 있습니다.
# - key가 틀리면 제출이 진행되지 않거나 잘못 제출되므로 태스크에 맞는 자기 key를 사용해야 합니다.

# %%
import aifactory.score as aif
import time
t = time.time()

#-----------------------------------------------------#
aif.submit(model_name="My_model",
           key="My_key"
           )
#-----------------------------------------------------#
print(time.time() - t)
# Out:
# file : task.py
# python
# 제출 완료
# 1.7257747650146484
